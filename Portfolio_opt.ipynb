# %% [markdown]
# <h1> <center> Partie 2 - Optimisation sous contrainte

# %%
from pulp import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('markowitz_dataset.xlsx')

# %%
returns_min = np.linspace(0, 0.057, 100)
returns = np.zeros_like(returns_min)
z = np.zeros_like(returns_min)
results = np.zeros_like(returns_min)


for j,r in enumerate(returns_min):
    model = pulp.LpProblem('linear_programming', LpMinimize)
    #Déclaration des variables
    Var = dict()
    for i,xi in enumerate(df['N°DPE']):
        Var.setdefault(xi,LpVariable(f"{xi}", lowBound=0))

    #Fonction objective à minimiser
    model += lpSum([Var[xi]*df['Emission_GES_kgCO2_m2_an'][i] for i,xi in enumerate(df['N°DPE'])])

    #Ajout des contraintes
    for i,xi in enumerate(df['N°DPE']):
        model += Var[xi] <= 1e8

    model += lpSum([Var[xi] for i,xi in enumerate(df['N°DPE'])]) == 2e9

    model += lpSum([Var[xi]*df['taux_credit'][i] for i,xi in enumerate(df['N°DPE'])]) >= 2e9*r

    #Résolution
    result = model.solve()
    results[j] = result
    returns[j] = sum([Var[xi].value()*df['taux_credit'][i] for i,xi in enumerate(df['N°DPE'])])/2e9
    z[j] = value(model.objective)/2e9
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f6d4fb785a7f4d8ca76cfc786b3c3be7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f6d4fb785a7f4d8ca76cfc786b3c3be7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (-279) rows, 276 (-2) columns and 276 (-558) elements
# 0  Obj 0 Primal inf 2e+09 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1970000000 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b4ad6c22cac447b29f7ce1a2b4495171-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b4ad6c22cac447b29f7ce1a2b4495171-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.0435232e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9c7bb32db7bd4968a8eb6a605e9c57e3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9c7bb32db7bd4968a8eb6a605e9c57e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.0870464e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/1ebd96db77274cde9a2db5aee1334c72-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/1ebd96db77274cde9a2db5aee1334c72-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.1305695e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6649fba850c44373b232643495b2b23d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6649fba850c44373b232643495b2b23d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.1740927e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/24d9659f1bcf4a96bb21c40c147fa6af-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/24d9659f1bcf4a96bb21c40c147fa6af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.2176159e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/d2b15e78e84948928154c97e255f9e17-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/d2b15e78e84948928154c97e255f9e17-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.2611391e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6b87ad34bf2f4d588931b92f91f73e67-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6b87ad34bf2f4d588931b92f91f73e67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.3046623e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/549f5f7d34374081ad023c7adb857e6a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/549f5f7d34374081ad023c7adb857e6a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.3481855e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/418f564c63994eb79eae5f457335c9fd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/418f564c63994eb79eae5f457335c9fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.3917086e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/38a9ee27958041b9a7341eb38b993ce7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/38a9ee27958041b9a7341eb38b993ce7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.4352318e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/8e6af59d949d446982ee6efb2d715b7a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/8e6af59d949d446982ee6efb2d715b7a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.478755e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/12447638c713418bb33033ff9eb68149-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/12447638c713418bb33033ff9eb68149-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.5222782e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fd540376836842eaa28f8c15fee9f2d3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fd540376836842eaa28f8c15fee9f2d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.5658014e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/407292d9ac08439ebc090a125ad9f591-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/407292d9ac08439ebc090a125ad9f591-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.6093245e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/af674b59ebc64be6a92dff11569a9cf6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/af674b59ebc64be6a92dff11569a9cf6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.6528477e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c7e86a7079f540cea838d91922a0e59b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c7e86a7079f540cea838d91922a0e59b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.6963709e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/15edcce0f06246b081ee2f0174c5839f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/15edcce0f06246b081ee2f0174c5839f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.7398941e+09 (2)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# After Postsolve, objective 1.97e+09, infeasibilities - dual 0 (0), primal 2.61936e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.97e+09 Primal inf 1e+08 (1)
# 1  Obj 1.97e+09
# Optimal - objective value 1.97e+09
# Optimal objective 1970000000 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dce5903220614f3fb3aa9be31a5f56bf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dce5903220614f3fb3aa9be31a5f56bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.7834173e+09 (2)
# 2  Obj 1.9718182e+09
# Optimal - objective value 1.9718182e+09
# After Postsolve, objective 1.9718182e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.9718182e+09 Primal inf 1.1818182e+08 (1)
# 2  Obj 1.9718182e+09
# Optimal - objective value 1.9718182e+09
# Optimal objective 1971818182 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e5d171b81c9a4f5dbc4e461e7ba3bce3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e5d171b81c9a4f5dbc4e461e7ba3bce3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.8269405e+09 (2)
# 2  Obj 1.974697e+09
# Optimal - objective value 1.974697e+09
# After Postsolve, objective 1.974697e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.974697e+09 Primal inf 1.469697e+08 (1)
# 2  Obj 1.974697e+09
# Optimal - objective value 1.974697e+09
# Optimal objective 1974696970 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/eb1b529e836146b181b2aa13e544f0ff-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/eb1b529e836146b181b2aa13e544f0ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.8704636e+09 (2)
# 2  Obj 1.9775758e+09
# Optimal - objective value 1.9775758e+09
# After Postsolve, objective 1.9775758e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1.9775758e+09 Primal inf 1.7575758e+08 (1)
# 2  Obj 1.9775758e+09
# Optimal - objective value 1.9775758e+09
# Optimal objective 1977575758 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9669f7a9a4724b2e9ac476c55d97b334-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9669f7a9a4724b2e9ac476c55d97b334-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.9139868e+09 (2)
# 3  Obj 1.9927273e+09
# Optimal - objective value 1.9927273e+09
# After Postsolve, objective 1.9927273e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.9927273e+09
# Optimal objective 1992727273 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ca726f276b8143e4928098f1a15656e0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ca726f276b8143e4928098f1a15656e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 2.95751e+09 (2)
# 3  Obj 2.0733333e+09
# Optimal - objective value 2.0733333e+09
# After Postsolve, objective 2.0733333e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.0733333e+09
# Optimal objective 2073333333 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e41fc9a38a9c4a1fb67595356fcf2b15-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e41fc9a38a9c4a1fb67595356fcf2b15-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.0010332e+09 (2)
# 3  Obj 2.1539394e+09
# Optimal - objective value 2.1539394e+09
# After Postsolve, objective 2.1539394e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2153939394 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/26b516c02cf746c5be8616fcb0515200-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/26b516c02cf746c5be8616fcb0515200-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.0445564e+09 (2)
# 3  Obj 2.2345455e+09
# Optimal - objective value 2.2345455e+09
# After Postsolve, objective 2.2345455e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.2345455e+09
# Optimal objective 2234545455 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/1020a8caba5d496083474da15b9b1370-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/1020a8caba5d496083474da15b9b1370-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.0880795e+09 (2)
# 3  Obj 2.3151515e+09
# Optimal - objective value 2.3151515e+09
# After Postsolve, objective 2.3151515e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.3151515e+09
# Optimal objective 2315151515 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/3588e40308994941a78e9c4784eefc3f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/3588e40308994941a78e9c4784eefc3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.1316027e+09 (2)
# 3  Obj 2.3957576e+09
# Optimal - objective value 2.3957576e+09
# After Postsolve, objective 2.3957576e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.3957576e+09
# Optimal objective 2395757576 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f9c6d001e3f14825863c32e3a92a7142-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f9c6d001e3f14825863c32e3a92a7142-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.1751259e+09 (2)
# 4  Obj 2.4763636e+09
# Optimal - objective value 2.4763636e+09
# After Postsolve, objective 2.4763636e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.4763636e+09
# Optimal objective 2476363636 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dbf3aa4e61fa4df8a8b8d43dd6483ea2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dbf3aa4e61fa4df8a8b8d43dd6483ea2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.2186491e+09 (2)
# 4  Obj 2.5569697e+09
# Optimal - objective value 2.5569697e+09
# After Postsolve, objective 2.5569697e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2556969697 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c916599d2eb04cc8891a2362bd0c0bd3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c916599d2eb04cc8891a2362bd0c0bd3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.2621723e+09 (2)
# 4  Obj 2.6375758e+09
# Optimal - objective value 2.6375758e+09
# After Postsolve, objective 2.6375758e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.6375758e+09
# Optimal objective 2637575758 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/55b734b000c24e4d8e179159c6f092c9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/55b734b000c24e4d8e179159c6f092c9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.3056955e+09 (2)
# 4  Obj 2.7181818e+09
# Optimal - objective value 2.7181818e+09
# After Postsolve, objective 2.7181818e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 2.7181818e+09
# Optimal objective 2718181818 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c80b06fc116d4ff69fd72244471f5c8d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/c80b06fc116d4ff69fd72244471f5c8d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.3492186e+09 (2)
# 4  Obj 2.7987879e+09
# Optimal - objective value 2.7987879e+09
# After Postsolve, objective 2.7987879e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2798787879 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/d4836d8d8af640fcb3c6286bfde52b60-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/d4836d8d8af640fcb3c6286bfde52b60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.3927418e+09 (2)
# 3  Obj 3.0236364e+09
# Optimal - objective value 3.0236364e+09
# After Postsolve, objective 3.0236364e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 3.0236364e+09
# Optimal objective 3023636364 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/22eb887c249e475da0cfcaefad12f529-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/22eb887c249e475da0cfcaefad12f529-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.436265e+09 (2)
# 3  Obj 3.33e+09
# Optimal - objective value 3.33e+09
# After Postsolve, objective 3.33e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 3.33e+09
# Optimal objective 3330000000 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b87c6f95540041ab9cf7a774e22d7d55-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b87c6f95540041ab9cf7a774e22d7d55-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.4797882e+09 (2)
# 3  Obj 3.7045455e+09
# Optimal - objective value 3.7045455e+09
# After Postsolve, objective 3.7045455e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 3.7045455e+09
# Optimal objective 3704545455 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2b47800f89c547bba322a1345daab510-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2b47800f89c547bba322a1345daab510-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.5233114e+09 (2)
# 3  Obj 4.1251515e+09
# Optimal - objective value 4.1251515e+09
# After Postsolve, objective 4.1251515e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 4.1251515e+09
# Optimal objective 4125151515 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9e5e2dd86e414a08a7f55496c54d79cd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9e5e2dd86e414a08a7f55496c54d79cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.5668345e+09 (2)
# 4  Obj 4.5672727e+09
# Optimal - objective value 4.5672727e+09
# After Postsolve, objective 4.5672727e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 4.5672727e+09 Primal inf 45454545 (1)
# 1  Obj 4.5672727e+09
# Optimal - objective value 4.5672727e+09
# Optimal objective 4567272727 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9e833ecce0d74a189a856505bde5a54d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9e833ecce0d74a189a856505bde5a54d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.6103577e+09 (2)
# 5  Obj 5.0163636e+09
# Optimal - objective value 5.0163636e+09
# After Postsolve, objective 5.0163636e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5016363636 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dc0f120b5e21486f8fd58812626b96e3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dc0f120b5e21486f8fd58812626b96e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.6538809e+09 (2)
# 3  Obj 5.4881818e+09
# Optimal - objective value 5.4881818e+09
# After Postsolve, objective 5.4881818e+09, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 5.4881818e+09
# Optimal objective 5488181818 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6e771c9f50c2427a99871651eca9b951-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6e771c9f50c2427a99871651eca9b951-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.6974041e+09 (2)
# 5  Obj 5.9718182e+09
# Optimal - objective value 5.9718182e+09
# After Postsolve, objective 5.9718182e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5971818182 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/772e92cc59a9421ab3107fe8014bfe26-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/772e92cc59a9421ab3107fe8014bfe26-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 3.7409273e+09 (2)
# 3  Obj 6.4566667e+09
# Optimal - objective value 6.4566667e+09
# After Postsolve, objective 6.4566667e+09, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 6.4566667e+09
# ...
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.7429936e+09 (2)
# 4  Obj 7.7715152e+10
# Optimal - objective value 7.7715152e+10
# After Postsolve, objective 7.7715152e+10, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 7.7715152e+10
# Optimal objective 7.771515152e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/76a5115850d441118e256575a4ff9bed-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/76a5115850d441118e256575a4ff9bed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.7865168e+09 (2)
# 4  Obj 8.0959091e+10
# Optimal - objective value 8.0959091e+10
# After Postsolve, objective 8.0959091e+10, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 8.0959091e+10
# Optimal objective 8.095909091e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9d0686a45784408c82e02b7007fad33d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9d0686a45784408c82e02b7007fad33d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.83004e+09 (2)
# 4  Obj 8.4246667e+10
# Optimal - objective value 8.4246667e+10
# After Postsolve, objective 8.4246667e+10, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 8.4246667e+10
# Optimal objective 8.424666667e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/16649fb52a314900a8164e15026a4295-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/16649fb52a314900a8164e15026a4295-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.8735632e+09 (2)
# 4  Obj 8.7560909e+10
# Optimal - objective value 8.7560909e+10
# After Postsolve, objective 8.7560909e+10, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 8.7560909e+10
# Optimal objective 8.756090909e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7218f21d434b4fa9b4ba3e19908ef682-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7218f21d434b4fa9b4ba3e19908ef682-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.9170864e+09 (2)
# 4  Obj 9.1039091e+10
# Optimal - objective value 9.1039091e+10
# After Postsolve, objective 9.1039091e+10, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 9.1039091e+10
# Optimal objective 9.103909091e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/bca8989053784ee7b1b1698255bca104-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/bca8989053784ee7b1b1698255bca104-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 5.9606095e+09 (2)
# 4  Obj 9.4620303e+10
# Optimal - objective value 9.4620303e+10
# After Postsolve, objective 9.4620303e+10, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 9.4620303e+10
# Optimal objective 9.462030303e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4108d35b079d4fadb8b0143bfcf8ba4d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4108d35b079d4fadb8b0143bfcf8ba4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.0041327e+09 (2)
# 4  Obj 9.8417576e+10
# Optimal - objective value 9.8417576e+10
# After Postsolve, objective 9.8417576e+10, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 9.8417576e+10
# Optimal objective 9.841757576e+10 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7bdd57058dce4e1d84f158fa8a1b9155-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7bdd57058dce4e1d84f158fa8a1b9155-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.0476559e+09 (2)
# 4  Obj 1.0370727e+11
# Optimal - objective value 1.0370727e+11
# After Postsolve, objective 1.0370727e+11, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.0370727e+11
# Optimal objective 1.037072727e+11 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ce81719272df486ea4c8165537343f82-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ce81719272df486ea4c8165537343f82-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.0911791e+09 (2)
# 4  Obj 1.0907717e+11
# Optimal - objective value 1.0907717e+11
# After Postsolve, objective 1.0907717e+11, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.0907717e+11
# Optimal objective 1.090771717e+11 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b553733df4e747afa56ee681aab60c1b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b553733df4e747afa56ee681aab60c1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.1347023e+09 (2)
# 4  Obj 1.1447071e+11
# Optimal - objective value 1.1447071e+11
# After Postsolve, objective 1.1447071e+11, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.1447071e+11
# Optimal objective 1.144707071e+11 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7d3e6e59bee94ec4a5998b771df3e336-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7d3e6e59bee94ec4a5998b771df3e336-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.1782254e+09 (2)
# 6  Obj 1.199097e+11
# Optimal - objective value 1.199097e+11
# After Postsolve, objective 1.199097e+11, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.199097e+11
# Optimal objective 1.19909697e+11 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2ae37f92e046455b99c2fed478edb005-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2ae37f92e046455b99c2fed478edb005-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.2217486e+09 (2)
# 5  Obj 1.2534869e+11
# Optimal - objective value 1.2534869e+11
# After Postsolve, objective 1.2534869e+11, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.2534869e+11
# Optimal objective 1.253486869e+11 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dace64be2e2347af9c27dd18118bd335-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/dace64be2e2347af9c27dd18118bd335-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.2652718e+09 (2)
# 4  Obj 1.3318889e+11
# Optimal - objective value 1.3318889e+11
# After Postsolve, objective 1.3318889e+11, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.3318889e+11
# Optimal objective 1.331888889e+11 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ecd90172790c42558cfa457cdb78f2a1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ecd90172790c42558cfa457cdb78f2a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 271 (-7) columns and 542 (-292) elements
# 0  Obj 0 Primal inf 6.308795e+09 (2)
# 4  Obj 1.4188667e+11
# Optimal - objective value 1.4188667e+11
# After Postsolve, objective 1.4188667e+11, infeasibilities - dual 0 (0), primal 3.7683716e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 1.4188667e+11
# Optimal objective 1.418866667e+11 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
plt.scatter(returns,z, c = results)
plt.title('Frontière efficiente')
plt.xlabel('Rendement')
plt.ylabel('émission de GES')
# Out:
# Text(0, 0.5, 'émission de GES')

# %%
emissions_max = np.linspace(10, 90, 150)
emissions = np.zeros_like(emissions_max)
z2 = np.zeros_like(emissions_max)
results2 = np.zeros_like(emissions_max)


for j,ges in enumerate(emissions_max):
    model = pulp.LpProblem('linear_programming', LpMaximize)
    #Déclaration des variables
    Var = dict()
    for i,xi in enumerate(df['N°DPE']):
        Var.setdefault(xi,LpVariable(f"{xi}", lowBound=0))

    #Fonction objective à minimiser
    model += lpSum([Var[xi]*df['taux_credit'][i] for i,xi in enumerate(df['N°DPE'])])

    #Ajout des contraintes
    for i,xi in enumerate(df['N°DPE']):
        model += Var[xi] <= 1e8

    model += lpSum([Var[xi] for i,xi in enumerate(df['N°DPE'])]) == 2e9

    model += lpSum([Var[xi]*df['Emission_GES_kgCO2_m2_an'][i] for i,xi in enumerate(df['N°DPE'])]) <= 2e9*ges

    #Résolution
    result = model.solve()
    results2[j] = result
    emissions[j] = sum([Var[xi].value()*df['Emission_GES_kgCO2_m2_an'][i] for i,xi in enumerate(df['N°DPE'])])/2e9
    z2[j] = value(model.objective)/2e9
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4aa5268cee5e445aa04b443a42a50711-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4aa5268cee5e445aa04b443a42a50711-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 66484396
# Optimal - objective value 66504854
# After Postsolve, objective 66504854, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 66504854.37 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2357744965124553a4f327ca559cd3d9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2357744965124553a4f327ca559cd3d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 8  Obj 67505756
# Optimal - objective value 67526940
# After Postsolve, objective 67526940, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 67526939.72 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9a57239a38094464876d1e062305ceb2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9a57239a38094464876d1e062305ceb2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 3  Obj 68494071
# Optimal - objective value 68516046
# After Postsolve, objective 68516046, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 68516046.37 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fa75674ed83e4e01bc031e54bc4a4e78-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fa75674ed83e4e01bc031e54bc4a4e78-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 69469387
# Optimal - objective value 69492251
# After Postsolve, objective 69492251, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 69492251.37 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/023c4d05f02b4ff2bd982b6276b74c36-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/023c4d05f02b4ff2bd982b6276b74c36-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 70428302
# Optimal - objective value 70452019
# After Postsolve, objective 70452019, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 70452019.31 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/8d76287325e146bb9c8198b12979f8f9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/8d76287325e146bb9c8198b12979f8f9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 5  Obj 71369621
# Optimal - objective value 71393972
# After Postsolve, objective 71393972, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 71393971.51 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/636b4573055b47e2ac346dc4bad54076-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/636b4573055b47e2ac346dc4bad54076-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 72310940
# Optimal - objective value 72335924
# After Postsolve, objective 72335924, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 72335923.7 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b470439090d24b43a8796f117e8ef912-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/b470439090d24b43a8796f117e8ef912-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 73252259
# Optimal - objective value 73277876
# After Postsolve, objective 73277876, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 73277875.9 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9975076c35df46239293aff01d959ff5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9975076c35df46239293aff01d959ff5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 3  Obj 74193578
# Optimal - objective value 74219828
# After Postsolve, objective 74219828, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 74219828.09 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4f9a78064f354de4854572171d0e2699-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4f9a78064f354de4854572171d0e2699-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 75124224
# Optimal - objective value 75151172
# After Postsolve, objective 75151172, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 75151171.75 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e3053f86e31c4ba6938e4faf301a0108-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e3053f86e31c4ba6938e4faf301a0108-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 75999371
# Optimal - objective value 76027325
# After Postsolve, objective 76027325, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 76027325
# Optimal objective 76027325.02 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e76127d6e62b4d2896e6c354e366262b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e76127d6e62b4d2896e6c354e366262b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 5  Obj 76765431
# Optimal - objective value 76794343
# After Postsolve, objective 76794343, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 76794343.24 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/acb179ec742d486393028266aeb4d93c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/acb179ec742d486393028266aeb4d93c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 77490150
# Optimal - objective value 77520468
# After Postsolve, objective 77520468, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 77520467.58 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/575e8a6f6c2b4d7e9c9a799149690652-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/575e8a6f6c2b4d7e9c9a799149690652-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 78188392
# Optimal - objective value 78219957
# After Postsolve, objective 78219957, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78219956.95 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/3d4d406c55b54c67ba7ea8eee8fcbaeb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/3d4d406c55b54c67ba7ea8eee8fcbaeb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 5  Obj 78863171
# Optimal - objective value 78895319
# After Postsolve, objective 78895319, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78895318.9 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/16b6e302ba6a4a999d504b07af9ce691-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/16b6e302ba6a4a999d504b07af9ce691-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 79507424
# Optimal - objective value 79540109
# After Postsolve, objective 79540109, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79540108.66 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/889b84b6b47b4c618340637f9a43dbe9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/889b84b6b47b4c618340637f9a43dbe9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 80135995
# Optimal - objective value 80169218
# After Postsolve, objective 80169218, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80169218.01 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9fdb369a8ed043ebb2b6a1e5bd7f5fd2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9fdb369a8ed043ebb2b6a1e5bd7f5fd2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 4  Obj 80738701
# Optimal - objective value 80772491
# After Postsolve, objective 80772491, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80772490.76 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/db431d45dece43f9af688557e3c40d7c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/db431d45dece43f9af688557e3c40d7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 81340997
# Optimal - objective value 81375764
# After Postsolve, objective 81375764, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 81375763.52 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/13e47840de8e4ae58aa5115745581d97-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/13e47840de8e4ae58aa5115745581d97-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 81943046
# Optimal - objective value 81979036
# After Postsolve, objective 81979036, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 81979036.27 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7c026d0202fb45ad80fff78531379610-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7c026d0202fb45ad80fff78531379610-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 82542301
# Optimal - objective value 82579056
# After Postsolve, objective 82579056, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 82579056
# Optimal objective 82579055.9 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0f1ca42334db4fe7b6c915d44e959da3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0f1ca42334db4fe7b6c915d44e959da3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 83135777
# Optimal - objective value 83173154
# After Postsolve, objective 83173154, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 83173154
# Optimal objective 83173154.36 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/92138afb6ef144d3a3a654b694357f32-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/92138afb6ef144d3a3a654b694357f32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 83715899
# Optimal - objective value 83753601
# After Postsolve, objective 83753601, infeasibilities - dual 0 (0), primal 1.3841858e-07 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 83753601
# Optimal objective 83753600.58 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f078e93d261b460f84314a0616694448-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f078e93d261b460f84314a0616694448-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 84279941
# Optimal - objective value 84318550
# After Postsolve, objective 84318550, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 84318550
# Optimal objective 84318549.78 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/5866c42cab8a4ed59c422f18f6002051-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/5866c42cab8a4ed59c422f18f6002051-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 84832121
# Optimal - objective value 84872068
# After Postsolve, objective 84872068, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 84872068
# Optimal objective 84872068.08 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ae3855f15fff40238ab6682c3c9addfe-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ae3855f15fff40238ab6682c3c9addfe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 85375800
# Optimal - objective value 85416989
# After Postsolve, objective 85416989, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 85416988.68 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6be84a7988664e74929e2ce6c1576443-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/6be84a7988664e74929e2ce6c1576443-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 85916923
# Optimal - objective value 85959325
# After Postsolve, objective 85959325, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 85959325
# Optimal objective 85959324.79 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/cba3d667164e49fda60f647f9cdf0b0f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/cba3d667164e49fda60f647f9cdf0b0f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 86455856
# Optimal - objective value 86499140
# After Postsolve, objective 86499140, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 86499140
# Optimal objective 86499140 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/5a8f2e991a394b3fb717746c768bbe1e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/5a8f2e991a394b3fb717746c768bbe1e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 9  Obj 86994207
# Optimal - objective value 87038365
# After Postsolve, objective 87038365, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 87038365.22 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fa64c2116e9f46dc998caf8a8b2ec890-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fa64c2116e9f46dc998caf8a8b2ec890-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 87527315
# Optimal - objective value 87572607
# After Postsolve, objective 87572607, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 87572606.76 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0f0992197f894dad8361be4239a11e79-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0f0992197f894dad8361be4239a11e79-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 88058875
# Optimal - objective value 88105277
# After Postsolve, objective 88105277, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 88105277
# Optimal objective 88105277.01 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f90c74bc2ba64e60bebca4fe082915ad-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f90c74bc2ba64e60bebca4fe082915ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 88584239
# Optimal - objective value 88631662
# After Postsolve, objective 88631662, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 88631662
# Optimal objective 88631662.06 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7c3044d8624a4256892d5fa5ddecd1af-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7c3044d8624a4256892d5fa5ddecd1af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 89107993
# Optimal - objective value 89156513
# After Postsolve, objective 89156513, infeasibilities - dual 0 (0), primal 1.5158789e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 89156513
# Optimal objective 89156512.67 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9ff3499e8c754dcbb02768bc34122f63-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/9ff3499e8c754dcbb02768bc34122f63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 89627997
# Optimal - objective value 89677787
# After Postsolve, objective 89677787, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 89677787
# Optimal objective 89677787.19 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0d1412c5a0ab44758a9c8da61eb97f8f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/0d1412c5a0ab44758a9c8da61eb97f8f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 90144423
# Optimal - objective value 90195270
# After Postsolve, objective 90195270, infeasibilities - dual 0 (0), primal 1.5158789e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 90195270
# Optimal objective 90195270.05 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/047b28b8a7104cbe8679966804196634-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/047b28b8a7104cbe8679966804196634-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 8  Obj 90655058
# Optimal - objective value 90706616
# After Postsolve, objective 90706616, infeasibilities - dual 0 (0), primal 1.5158789e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 90706616
# Optimal objective 90706615.53 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ab4f887b5475418e89aae989ec652ec6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ab4f887b5475418e89aae989ec652ec6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 91156522
# Optimal - objective value 91209004
# After Postsolve, objective 91209004, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 91209004
# Optimal objective 91209003.71 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7eed54ebd2de40a19fd1e158106fa5ac-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7eed54ebd2de40a19fd1e158106fa5ac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 9  Obj 91645643
# Optimal - objective value 91699335
# After Postsolve, objective 91699335, infeasibilities - dual 0 (0), primal 7.5293945e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 91699335
# Optimal objective 91699334.99 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ad3c33417a7e43949b46f85daeee787c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ad3c33417a7e43949b46f85daeee787c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 92134764
# Optimal - objective value 92189666
# ...
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 10  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 10 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ea7592135bd543e6b3ef875d805aaa44-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/ea7592135bd543e6b3ef875d805aaa44-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 10  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 10 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/41a597a3a15a4a3ca63772333f435b62-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/41a597a3a15a4a3ca63772333f435b62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 10  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 10 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4c753451f46d42b6959475f90e1815c5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/4c753451f46d42b6959475f90e1815c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 8  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/38edd05df3494afcb088e97ec2d8b43c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/38edd05df3494afcb088e97ec2d8b43c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 8  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/32e6cef3363f436baf1fc0704af7ebb7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/32e6cef3363f436baf1fc0704af7ebb7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 8  Obj 1.1488266e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/cf447ca0535a4cabac4ac7cef5538d3e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/cf447ca0535a4cabac4ac7cef5538d3e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2ca9711a7489416fbc8f3527aa768c47-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/2ca9711a7489416fbc8f3527aa768c47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e829e441711346baaedec83ec23d42df-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/e829e441711346baaedec83ec23d42df-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fd34e81bf0894492993cd7042211b686-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fd34e81bf0894492993cd7042211b686-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fbc2cc3ca2744e10ae6a21b4c6488ebd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fbc2cc3ca2744e10ae6a21b4c6488ebd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7ade9b3e06ec41aaace38f0f3d6ba71a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/7ade9b3e06ec41aaace38f0f3d6ba71a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fff29d85d95546f0a36a92487564bb03-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/fff29d85d95546f0a36a92487564bb03-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 6  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - cbc /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f85c86d0796442a5a0ae224daa7d35c4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/lg7k599d1vb29gj0p2dj2rfr0000gn/T/f85c86d0796442a5a0ae224daa7d35c4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 285 COLUMNS
# At line 1398 RHS
# At line 1679 BOUNDS
# At line 1680 ENDATA
# Problem MODEL has 280 rows, 278 columns and 834 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-278) rows, 199 (-79) columns and 398 (-436) elements
# Perturbing problem by 0.001% of 0.41853401 - largest nonzero change 5.0329414e-05 ( 0.35835866%) - largest zero change 0
# 0  Obj -0 Primal inf 2e+09 (1) Dual inf 14.870941 (199)
# 7  Obj 1.148661e+08
# Optimal - objective value 1.15e+08
# After Postsolve, objective 1.15e+08, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 115000000 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
plt.scatter(z2,emissions, label = "Maximisation des rendements")
plt.scatter(returns,z, label = "Minimisation des GES ")
plt.title('Frontière efficiente')
plt.ylabel('émission de GES')
plt.xlabel('Rendement')
plt.legend()
plt.show()
